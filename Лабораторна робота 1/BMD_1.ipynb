# %% [markdown]
# <h1 color="#ddd">
#    Обробка та аналіз БМД
#    Група: БС-81
#    Лобунько Д.О.
# </h1>

# %%
import pandas as pd
import os

# %% [markdown]
# 1. DataFrame

# %%
myFrame = pd.DataFrame(
{
    "Назва процесора": ["Intel core i9 9900", "Intel Xeon E5-2660", "AMD Ryzen 7 2700X", "AMD Ryzen 5 3600"],
    "Тактова частота, ГГц": [3.6, 2.0, 3.7, 3.8],
    "Кількість ядер": [8, 14, 8, 6],
    "Багатопотоковість": [False, False, True, True],
    "Кеш-пам'ять, Мб": ["2+16", "3+35", "4+16", "3+32"],
    "Кількість ват, Вт": [95, 105, 105, 95]
})
myFrame
# Out:
#       Назва процесора  Тактова частота, ГГц  Кількість ядер  \
# 0  Intel core i9 9900                   3.6               8
# 1  Intel Xeon E5-2660                   2.0              14
# 2   AMD Ryzen 7 2700X                   3.7               8
# 3    AMD Ryzen 5 3600                   3.8               6
#
#    Багатопотоковість Кеш-пам'ять, Мб  Кількість ват, Вт
# 0              False            2+16                 95
# 1              False            3+35                105
# 2               True            4+16                105
# 3               True            3+32                 95

# %% [markdown]
# 2. Завантаження даних з CSV файлу

# %%
path = "C:/dima/programming/Jupyter/ramen-ratings.csv"
data = pd.read_csv(path, encoding="utf-8")

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print("The directory we are working in: {}".format(os.getcwd()))
# Out:
# The directory we are working in: C:\Users\Дима

# %% [markdown]
# 3. Відображення завантажених даних

# %%
data
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %% [markdown]
# 4. Базова статистика про завантажені дані

# %%
data.shape
# Out:
# (2580, 7)

# %%
data.head(5)
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
data.tail(5)
# Out:
#       Review #     Brand                                            Variety  \
# 2575         5     Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...
# 2576         4   Wai Wai                     Oriental Style Instant Noodles
# 2577         3   Wai Wai                                     Tom Yum Shrimp
# 2578         2   Wai Wai                               Tom Yum Chili Flavor
# 2579         1  Westbrae                                         Miso Ramen
#
#      Style   Country Stars Top Ten
# 2575  Bowl   Vietnam   3.5     NaN
# 2576  Pack  Thailand     1     NaN
# 2577  Pack  Thailand     2     NaN
# 2578  Pack  Thailand     2     NaN
# 2579  Pack       USA   0.5     NaN

# %%
data.dtypes
# Out:
# Review #     int64
# Brand       object
# Variety     object
# Style       object
# Country     object
# Stars       object
# Top Ten     object
# dtype: object

# %%
data.describe()
# Out:
#           Review #
# count  2580.000000
# mean   1290.500000
# std     744.926171
# min       1.000000
# 25%     645.750000
# 50%    1290.500000
# 75%    1935.250000
# max    2580.000000

# %% [markdown]
# 5. Використання функції "describe"

# %%
data['Brand'].describe()
# Out:
# count       2580
# unique       355
# top       Nissin
# freq         381
# Name: Brand, dtype: object

# %%
data['Variety'].describe()
# Out:
# count        2580
# unique       2413
# top       Chicken
# freq            7
# Name: Variety, dtype: object

# %%
cur_data = data.iloc[0:10, :]
cur_data
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
# 5      2575   Samyang Foods
# 6      2574         Acecook
# 7      2573     Ikeda Shoku
# 8      2572      Ripe'n'Dry
# 9      2571            KOKA
#
#                                              Variety Style      Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup        Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack       Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup          USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack       Taiwan  2.75
# 4                                    Singapore Curry  Pack        India  3.75
# 5                             Kimchi song Song Ramen  Pack  South Korea  4.75
# 6                Spice Deli Tantan Men With Cilantro   Cup        Japan     4
# ...

# %%
new_data = ["gr1","gr1","gr1","gr1","gr1","gr2","gr2","gr2","gr2","gr2"]
cur_data.insert(3,"Group",new_data)
cur_data
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
# 5      2575   Samyang Foods
# 6      2574         Acecook
# 7      2573     Ikeda Shoku
# 8      2572      Ripe'n'Dry
# 9      2571            KOKA
#
#                                              Variety Group Style      Country  \
# 0                          T's Restaurant Tantanmen    gr1   Cup        Japan
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...   gr1  Pack       Taiwan
# 2                      Cup Noodles Chicken Vegetable   gr1   Cup          USA
# 3                      GGE Ramen Snack Tomato Flavor   gr1  Pack       Taiwan
# 4                                    Singapore Curry   gr1  Pack        India
# 5                             Kimchi song Song Ramen   gr2  Pack  South Korea
# 6                Spice Deli Tantan Men With Cilantro   gr2   Cup        Japan
# ...

# %% [markdown]
# 6. Виведення статистики з розділенням на групи

# %%
cur_data.groupby('Group').describe()
# Out:
#       Review #
#          count    mean       std     min     25%     50%     75%     max
# Group
# gr1        5.0  2578.0  1.581139  2576.0  2577.0  2578.0  2579.0  2580.0
# gr2        5.0  2573.0  1.581139  2571.0  2572.0  2573.0  2574.0  2575.0

# %%
cur_data.to_csv("output.csv", encoding='utf-8')
data.describe().to_csv("output_describe.csv", encoding='utf-8')
